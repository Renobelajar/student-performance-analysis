# %% [markdown]
# 1. Menampilkan Dataset

# %%
import pandas as pd

# Membaca data
df = pd.read_csv('data_pelatihan.csv')

# Menampilkan data
df.sample(10)
# Out:
#       ID   Nama  Umur     Gender  Nilai      Matkul    Tanggal   UTS   UAS
# 73  74.0   Andy  21.0  Laki-laki   76.0     Biologi   9/8/2023  82.0  70.0
# 31  32.0   Dino  24.0  Laki-laki   85.5       Kimia  15/8/2023  92.0  79.0
# 91  92.0  Wahyu  24.0  Laki-laki   77.5      Fisika   9/8/2023  78.0  77.0
# 21  22.0   Andi  20.0  Laki-laki   87.5     Biologi   9/8/2023  81.0  94.0
# 23  24.0   Bayu  22.0  Laki-laki   91.5      Fisika  15/8/2023  90.0  93.0
# 62  63.0   Nova  22.0  Perempuan   76.5  Matematika  15/8/2023  80.0  73.0
# 49  50.0  Fandi  23.0  Laki-laki   80.5  Matematika  15/8/2023  70.0  91.0
# 82  83.0   Tina  22.0  Perempuan   87.0  Matematika   9/8/2023  81.0  93.0
# 98  99.0   Febi  22.0  Perempuan   72.0     Biologi  15/8/2023  74.0  70.0
# 48  49.0   Tika  20.0  Perempuan   86.0       Kimia  15/8/2023  79.0  93.0
